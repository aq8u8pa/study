# %% [markdown]
# # 04-python.ipynb
# ## Hello World!

# %% [markdown]
# 파이썬이 제대로 작동하는지 간단하게 확인하는 고전적인 방법을 써봅시다
#
# 1. 우분투 쉘 열고
# 2. 가상환경 활성화,  학습용 파일로 이동,  VSCode 실행, `01-python` 폴더로 이동

# %%
conda activate p11
cd study
code .
cd 01-python

# %% [markdown]
# 3. VSCode의 왼쪽 바에 보이는 `01-python` 폴더 안에 새 파일을 생성
#   * `[파일명].py`
#   * 나는 앞으로 만드는 모든 코드를 순서대로 정렬하고 싶다: 파일명 앞에 `001-` 붙이세요
# 4. 파일 안에 아래 코드를 작성

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Ctrl+S로 저장
#     5. 우분투 쉘에 아래 코드를 입력해서 실행해봅니다

# %%
python3 [파일명].py
